# %% [markdown]
# <a href="https://colab.research.google.com/github/rbelay1/Final-Project/blob/main/Copy_of_Copy_of_Df_of_Brown_Noser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install trafilatura
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: trafilatura in /usr/local/lib/python3.10/dist-packages (1.5.0)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (4.9.2)
# Requirement already satisfied: courlan>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (0.9.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2022.12.7)
# Requirement already satisfied: charset-normalizer>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (3.1.0)
# Requirement already satisfied: htmldate>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (1.4.3)
# Requirement already satisfied: justext>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (3.0.0)
# Requirement already satisfied: urllib3<2,>=1.26 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (1.26.15)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.10/dist-packages (from courlan>=0.9.0->trafilatura) (0.13)
# Requirement already satisfied: langcodes>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from courlan>=0.9.0->trafilatura) (3.3.0)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.4.2->trafilatura) (1.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.4.2->trafilatura) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2022.7.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->htmldate>=1.4.2->trafilatura) (1.16.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2023.3)

# %%
import requests
import os 
from bs4 import BeautifulSoup
from trafilatura import fetch_url
from trafilatura import extract
import pandas as pd
data =[]
for issue in range(26,124):
  url = f'http://thenoser.com/issue/{issue}'
  reqs = requests.get(url)
  soup = BeautifulSoup(reqs.text, 'html.parser')
  counter = 0
  for link in soup.find_all('a'):
      if '/article/' in link.get('href'):
        article_url = f"http://thenoser.com{link.get('href')}"
        try: 
          article_html = fetch_url(article_url)
          article_text = extract(article_html)
          data.append([article_url,issue,counter,article_text])
          data = list(set(map(tuple, data)))
          counter+=1
        except:
          print(f"Error occurred while processing {article_url}")
          pass
df = pd.DataFrame(data,columns=['url','issue number','article number','text'])

# %%
from textblob import TextBlob

for article in data:
    text = article[:]
    sentiment = TextBlob(text).sentiment.polarity
    article.append(sentiment)

df = pd.DataFrame(data, columns=['url', 'issue number', 'article number', 'text', 'sentiment'])

# %%
df
# Out:
#                                                     url  issue number  \
# 0     http://thenoser.com/article/Simmons-Leaves-To-...            26
# 1     http://thenoser.com/article/Simmons-Leaves-To-...            26
# 2     http://thenoser.com/article/Simmons-Leaves-To-...            26
# 3     http://thenoser.com/article/Bagel-Gourmet-to-O...            26
# 4     http://thenoser.com/article/Bagel-Gourmet-to-O...            26
# ...                                                 ...           ...
# 1813  http://thenoser.com/article/Musical-Set-In-195...           123
# 1814  http://thenoser.com/article/17-Year-Olds-Top-G...           123
# 1815  http://thenoser.com/article/17-Year-Olds-Top-G...           123
# 1816  http://thenoser.com/article/Movie-Would-Be-Bet...           123
# 1817  http://thenoser.com/article/Movie-Would-Be-Bet...           123
#
#       article number                                               text
# 0                  0  Following inquiries into to the cause of her r...
# 1                  1  Following inquiries into to the cause of her r...
# 2                  2  Following inquiries into to the cause of her r...
# 3                  3  Serving quality Mexican food and excessive amo...
# 4                  4  Serving quality Mexican food and excessive amo...
# ...              ...                                                ...
# 1813              23  Reports indicate that modern musical Against t...
# 1814              24  According to local sources, 17-year-old Devon ...
# 1815              25  According to local sources, 17-year-old Devon ...
# 1816              26  According to sources, area man Josh Gruff thin...
# 1817              27  According to sources, area man Josh Gruff thin...
#
# [1818 rows x 4 columns]

# %%
df[(df['article number'] == 4) & (df['issue number'] == 33)]
# Out:
#                                                   url  issue number  \
# 73  http://thenoser.com/issue/33//article/sophomor...            33
#
#     article number                                               text
# 73               4  Colin Brady '10 envies most of his fellow Brow...

# %%
from trafilatura import extract
listofarticles = df[url]
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
tokens = text.split()

from nltk.tag import pos_tag
print(pos_tag(tokens))

from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

print(lemmatize_sentence(tokens))
lemmatized_tokens = lemmatize_sentence(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-07eba35001cb> in <cell line: 6>()
#       4 nltk.download('wordnet')
#       5 nltk.download('averaged_perceptron_tagger')
# ----> 6 tokens = text.split()
#       7
#       8 from nltk.tag import pos_tag
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

import re, string

def remove_noise(tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tokens):
        #token = re.sub('(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
        #               '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        #token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens
    print(cleaned_tokens)
print(lemmatized_tokens)
new_tokens = remove_noise(tokens, stop_words)
print(new_tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cd8ae87ad555> in <cell line: 29>()
#      27     return cleaned_tokens
#      28     print(cleaned_tokens)
# ---> 29 print(lemmatized_tokens)
#      30 new_tokens = remove_noise(tokens, stop_words)
#      31 print(new_tokens)
#
# NameError: name 'lemmatized_tokens' is not defined
